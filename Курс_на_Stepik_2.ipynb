# %% [markdown]
# <a href="https://colab.research.google.com/github/ratatatan/itmo-oomd/blob/prac1/%D0%9A%D1%83%D1%80%D1%81_%D0%BD%D0%B0_Stepik_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Сделайте копию колаба (файл => создать копию на диске). Переименуйте, добавив в название ФИО и номер группы

# %% [markdown]
# Модуль 1 называется "Введение" и в нем нет никаких содержательных заданий. Поэтому начинаем сразу с модуля 2.

# %% [markdown]
# # Модуль 2. Устройство изображения. Работа с изображением в Python

# %% [markdown]
# В документе есть ссылки на короткие видео с пояснениями и задания. В принципе задания можно попробовать выполнить на Степике, но при этом обязательно все решения и результаты тестов нужно поместить в этом колабе. Решения нужно помещать сразу после соответствующего задания.

# %% [markdown]
# ## 2.1 Цифровое изображение. Чтение, запись работа с пикселями

# %% [markdown]
# Видео урока: https://stepik.org/lesson/58180/step/1

# %% [markdown]
# **Задание 1. Нестандартный формат изображений**
#
# Предположим, что вы хотите хранить цветные изображения с указанием прозрачности каждого пикселя. Для каждого пикселя потребуется хранить четыре числа: три цветных компоненты (R, G и B) со значениями в диапазоне [0..31] каждая и компоненту прозрачности — число в диапазоне [0..63]. Сколько бит потребуется для хранения значений одного пикселя?

# %%
from numpy import log2
log2(32)*3+log2(64)
# Out:
# np.float64(21.0)

# %% [markdown]
# Видео урока: https://stepik.org/lesson/58180/step/3

# %% [markdown]
# **Задание 2. Количество столбцов**
#
# Прочитайте изображение из файла img.png и выведите количество столбцов этого изображения на стандартный вывод.
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58180/img.png
#
# *Sample Output:*
#
# 419

# %% [markdown]
# Напоминаю, что скачать картинку можно через `wget`

# %%
! wget https://stepik.org/media/attachments/lesson/58180/img.png
# Out:
# --2025-03-19 18:52:55--  https://stepik.org/media/attachments/lesson/58180/img.png
# Resolving stepik.org (stepik.org)... 178.248.239.111
# Connecting to stepik.org (stepik.org)|178.248.239.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240241 (235K) [image/png]
# Saving to: ‘img.png’
#
# img.png             100%[===================>] 234.61K   508KB/s    in 0.5s
#
# 2025-03-19 18:52:57 (508 KB/s) - ‘img.png’ saved [240241/240241]

# %%
import skimage.io as io

# %%
pic = io.imread('./img.png')
io.imshow(pic)
# Out:
# <ipython-input-5-a4f2f2509566>:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(pic)

# %%
pic.shape[1]
# Out:
# 800

# %% [markdown]
# **Задание 3. Изменение цвета пикселя изображения**

# %% [markdown]
# Прочитайте изображение из файла img.png. У этого изображения нечетное количество строк и столбцов. Поменяйте цвет центрального пикселя этого изображения на зеленый цвет rgb (102, 204, 102) и сохраните изображение в файл out_img.png.
#
# В примере входа и выхода указаны ссылки на файлы. Это сделано для вашего удобства. Вы можете скачать эти файлы, сохранить вход как img.png и протестировать решение на своем компьютере, сравнив с выходным изображением.
#
# Для сравнения двух изображений можно воспользоваться функцией [numpy.array_equal](https://numpy.org/doc/stable/reference/generated/numpy.array_equal.html).
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58180/tiger-color.png
#
# *Sample Output:*
#
# https://stepik.org/media/attachments/lesson/58180/tiger-color-green-pixel.png

# %% [markdown]
# Видео урока: https://stepik.org/lesson/58180/step/6

# %%
! wget -O img.png https://stepik.org/media/attachments/lesson/58180/tiger-color.png
# Out:
# --2025-03-19 20:03:28--  https://stepik.org/media/attachments/lesson/58180/tiger-color.png
# Resolving stepik.org (stepik.org)... 178.248.239.111
# Connecting to stepik.org (stepik.org)|178.248.239.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 892353 (871K) [image/png]
# Saving to: ‘img.png’
#
# img.png             100%[===================>] 871.44K  1.25MB/s    in 0.7s
#
# 2025-03-19 20:03:30 (1.25 MB/s) - ‘img.png’ saved [892353/892353]

# %%
pic = io.imread("img.png")
pic[pic.shape[0]//2+1, pic.shape[1]//2+1] = [102, 204, 102]
io.imsave("out_img.png", pic)

# %% [markdown]
# **Задание 4. Изменение цвета прямоугольника**
#
# Загрузите изображение из файла img.png. Оно имеет нечетное количество строк и столбцов. В центре этого изображения находится прямоугольник размером 7 строк и 15 столбцов. Поменяйте его цвет на розовый rgb(255, 192, 203) и сохраните в файл out_img.png.
#
# В примере входа и выхода указаны ссылки на файлы. Это сделано для вашего удобства. Вы можете скачать эти файлы, сохранить вход как img.png и протестировать решение на своем компьютере, сравнив с выходным изображением.
#
# Для сравнения двух изображений можно воспользоваться функцией numpy.array_equal.
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58180/tiger-gray.png
#
# *Sample Output:*
#
# https://stepik.org/media/attachments/lesson/58180/tiger-pink.png

# %%
! wget -O img.png https://stepik.org/media/attachments/lesson/58180/tiger-gray.png
# Out:
# --2025-03-19 20:52:00--  https://stepik.org/media/attachments/lesson/58180/tiger-gray.png
# Resolving stepik.org (stepik.org)... 178.248.239.111
# Connecting to stepik.org (stepik.org)|178.248.239.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 914190 (893K) [image/png]
# Saving to: ‘img.png’
#
# img.png             100%[===================>] 892.76K  1.30MB/s    in 0.7s
#
# 2025-03-19 20:52:01 (1.30 MB/s) - ‘img.png’ saved [914190/914190]

# %%
pic = io.imread("img.png")
h, w, _ = pic.shape
pic[h//2-3:h//2+4, w//2-7:w//2+8] = [255, 192, 203]
io.imsave("out_img.png", pic)

# %% [markdown]
# **Задание 5. Определение рамки изображения**
#
# Загрузите изображение из файла img.png. Изображение состоит из рамки сплошного цвета и внутренней части изображения. Цвет рамки можно узнать, посмотрев на левый верхний пиксель. Рамка может иметь разную ширину со всех четырех сторон. Определите размеры рамки и выведите эти размеры через пробел. Размеры рамки выводите в следующем порядке: левый, верхний, правый, нижний.
#
# В примере входа указана ссылка на изображение. Это сделано для вашего удобства. Вы можете скачать этот файл, сохранить вход как img.png и протестировать решение на своем компьютере.
#
# Отдельно укажите ограничения вашего алгоритма. В каких случаях от отработает некорректно?
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58180/tiger-border.png
#
# *Sample Output:*
#
# 1 39 25 7

# %%
! wget -O img.png https://stepik.org/media/attachments/lesson/58180/tiger-border.png
# Out:
# --2025-03-19 20:52:56--  https://stepik.org/media/attachments/lesson/58180/tiger-border.png
# Resolving stepik.org (stepik.org)... 178.248.239.111
# Connecting to stepik.org (stepik.org)|178.248.239.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 971534 (949K) [image/png]
# Saving to: ‘img.png’
#
# img.png             100%[===================>] 948.76K  1.21MB/s    in 0.8s
#
# 2025-03-19 20:52:57 (1.21 MB/s) - ‘img.png’ saved [971534/971534]

# %%
pic = io.imread("img.png")
h, w, _ = pic.shape
border_color = pic[0, 0]

left = sum(all(pic[h//2, i] == border_color) for i in range(0, w//2))
right = sum(all(pic[h//2, i] == border_color) for i in range(w//2, w))
top = sum(all(pic[i, w//2] == border_color) for i in range(0, h//2))
bottom = sum(all(pic[i, w//2] == border_color) for i in range(h//2, h))

left, top, right, bottom

# Алгоритм не будет работать в случае, если рамка проходит через центр
# изображения. Тогда программа присвоит часть пикселей одной стороны
# другим сторонам
# Out:
# (1, 39, 25, 7)

# %% [markdown]
# ## 2.2 Арифметические операции. Каналы. Вычисление яркости изображения

# %% [markdown]
# Видео урока: https://stepik.org/lesson/58181/step/1

# %% [markdown]
# **Задание 1. Вычисление негатива изображения**
#
# Прочитайте изображение из файла img.png. У этого изображения нечетное количество строк и столбцов. Вычислите негатив изображения и сохраните его в файл out_img.png.
#
# В примере входа и выхода указаны ссылки на файлы. Это сделано для вашего удобства. Вы можете скачать эти файлы, сохранить вход как img.png и протестировать решение на своем компьютере, сравнив с выходным изображением.
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58181/tiger-color.png
#
# *Sample Output:*
#
# https://stepik.org/media/attachments/lesson/58181/tiger-negative.png

# %% [markdown]
# Видео урока: https://stepik.org/lesson/58181/step/3

# %%
! wget -O img.png https://stepik.org/media/attachments/lesson/58181/tiger-color.png
# Out:
# --2025-03-19 21:24:31--  https://stepik.org/media/attachments/lesson/58181/tiger-color.png
# Resolving stepik.org (stepik.org)... 178.248.239.111
# Connecting to stepik.org (stepik.org)|178.248.239.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 956584 (934K) [image/png]
# Saving to: ‘img.png’
#
# img.png             100%[===================>] 934.16K  1.30MB/s    in 0.7s
#
# 2025-03-19 21:24:33 (1.30 MB/s) - ‘img.png’ saved [956584/956584]

# %%
from skimage import img_as_float, img_as_ubyte
from numpy import dstack
pic = img_as_float(io.imread("img.png"))
pic = 1 - pic
io.imsave("out_img.png", img_as_ubyte(pic))

# %% [markdown]
# **Задание 2. Поменять местами каналы изображения**
#
# Загрузите изображение из файла img.png. У этого изображения поменяйте местами каналы так, чтобы вместо порядка RGB каналы шли в порядке BRG. Сохраните изображение с измененными каналами в файл out_img.png.
#
# В примере входа и выхода указаны ссылки на файлы. Это сделано для вашего удобства. Вы можете скачать эти файлы, сохранить вход как img.png и протестировать решение на своем компьютере, сравнив с выходным изображением.
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58181/tiger-color.png
#
# *Sample Output:*
#
# https://stepik.org/media/attachments/lesson/58181/tiger-brg.png

# %% [markdown]
# Видео урока: https://stepik.org/lesson/58181/step/5

# %%
! wget -O img.png https://stepik.org/media/attachments/lesson/58181/tiger-color.png
# Out:
# --2025-03-19 21:41:30--  https://stepik.org/media/attachments/lesson/58181/tiger-color.png
# Resolving stepik.org (stepik.org)... 178.248.239.111
# Connecting to stepik.org (stepik.org)|178.248.239.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 956584 (934K) [image/png]
# Saving to: ‘img.png’
#
# img.png             100%[===================>] 934.16K  1.35MB/s    in 0.7s
#
# 2025-03-19 21:41:31 (1.35 MB/s) - ‘img.png’ saved [956584/956584]

# %%
pic = io.imread("img.png")
pic[:, :, 0], pic[:, :, 2] = pic[:, :, 2], pic[:, :, 0]
io.imsave("out_img.png", pic)

# %% [markdown]
# **Задание 3. Подсчет яркости изображения**
#
# Загрузите цветное изображение из файла img.png. Подсчитайте яркость этого изображения и сохраните в файл out_img.png. Результирующее изображение должно быть одноканальным. Для подсчета яркости используйте формулу
# Y=0.2126⋅R+0.7152⋅G+0.0722⋅B.
#
# В примере входа и выхода указаны ссылки на файлы. Это сделано для вашего удобства. Вы можете скачать эти файлы, сохранить вход как img.png и протестировать решение на своем компьютере, сравнив с выходным изображением.
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58181/tiger-color.png
#
# *Sample Output:*
#
# https://stepik.org/media/attachments/lesson/58181/tiger-y.png

# %%
! wget -O img.png https://stepik.org/media/attachments/lesson/58181/tiger-color.png

# %%
from numpy import uint8
pic = io.imread("img.png")
Y = pic[:, :, 0] * 0.2126 + pic[:, :, 1] * 0.7152 + pic[:, :, 2] * 0.0722
io.imsave("out_img.png", Y.astype(uint8))

# %% [markdown]
# ## 2.3 Сопоставление фотографий Прокудина-Горского

# %% [markdown]
# Видео с объяснением задания: https://stepik.org/lesson/58182/step/1

# %% [markdown]
# **Задание 1. Сопоставление фотографий Прокудина-Горского**
#
# Напишите функцию `align`, которая сопоставляет изображения с фотографий Прокудина-Горского и возвращает координаты точек на синем и красном каналах, как это описано в видео, [слайдах](https://stepik.org/media/attachments/lesson/58182/slides-7.pdf) и [описании задания](https://stepik.org/media/attachments/lesson/58182/channel_align.pdf).
#
#
# Прототип функции:
# ```
# def align(img, g_coord):
#     row_g, col_g = g_coord
#     # считаем сдвиги каналов
#
#     # сдвигаем точку на зеленом канале
#     # на другие каналы
#     return (row_b, col_b), (row_r, col_r)
# ```
#
#
# Для вашего удобства приводится один тест. Вход: ссылка на изображение, координаты точки на зеленом канале. Выход: правильный ответ — координаты точек на синем и красном каналах.
#
# Программа не должна ничего читать и писать на стандартный ввод и вывод, необходимо написать только функцию align.
# Протестируйте программу на 10 картинках.
# * https://stepik.org/media/attachments/lesson/58182/00.png
# * https://stepik.org/media/attachments/lesson/58182/01.png
# * https://stepik.org/media/attachments/lesson/58182/02.png
# * https://stepik.org/media/attachments/lesson/58182/03.png
# * https://stepik.org/media/attachments/lesson/58182/04.png
# * https://stepik.org/media/attachments/lesson/58182/05.png
# * https://stepik.org/media/attachments/lesson/58182/06.png
# * https://stepik.org/media/attachments/lesson/58182/07.png
# * https://stepik.org/media/attachments/lesson/58182/08.png
# * https://stepik.org/media/attachments/lesson/58182/09.png
#
# Для этого достаточно проверить, что изображения сопоставляются качественно, без визуальных артефактов.
#
# *Sample Input:*
#
# https://stepik.org/media/attachments/lesson/58182/00.png 508,237
#
# *Sample Output:*
#
# 153,236,858,238

# %%
! wget -O test.png https://stepik.org/media/attachments/lesson/58182/08.png

from numpy import roll
from math import ceil, floor

#def trim(img, p = 0.1):
#  h, w = img.shape
#  return img[int(h*p):int(h*(1-p)), int(w*p):int(w*(1-p))]

#def correlation(x, g):
#  return (x * g).sum()

def align(img, g_coord):
    row_g, col_g = g_coord

    img = img_as_float(img)
    h, w = img.shape

    b = pic[int(h*0.05):int(h//3-h*0.05), int(w*0.1):int(w-w*0.1)]
    g = pic[int(h//3+h*0.05):int(h//3*2-h*0.05), int(w*0.1):int(w-w*0.1)]
    r = pic[int(h//3*2+h*0.05):int(h//3*3-h*0.05), int(w*0.1):int(w-w*0.1)]
    # h_size = int(h//3-h*0.1)
    # h_margin = int(h*0.05)
    # w_size = int(w-w*0.1)
    # w_margin = int(w*0.05)
    # b = img[h_margin:h_margin+h_size, w_margin:w_margin+w_size]
    # g = img[h_margin*2+h_size:h_margin*2+h_size*2, w_margin:w_margin+w_size]
    # r = img[h_margin*3+h_size*2:h_margin*3+h_size*3, w_margin:w_margin+w_size]

    # считаем сдвиги каналов
    best_correlation = 0
    best_shift = (0, 0)
    for x in range(-15, 16):
      for y in range(-15, 16):
        cor = (roll(roll(b, y, 0), x, 1) * g).sum()
        if cor > best_correlation:
          best_correlation = cor
          best_shift = (x, y)
    best_b_shift = best_shift

    best_correlation = 0
    best_shift = (0, 0)
    for x in range(-15, 16):
      for y in range(-15, 16):
        cor = ((roll(roll(r, y, 0), x, 1)) * g).sum()
        if cor > best_correlation:
          best_correlation = cor
          best_shift = (x, y)
    best_r_shift = best_shift

    row_b, col_b = row_g + best_b_shift[1], col_g + best_b_shift[0]
    row_r, col_r = row_g + best_r_shift[1], col_g + best_r_shift[0]

    # сдвигаем точку на зеленом канале
    # на другие каналы
    return (row_b, col_b), (row_r, col_r)

pic = img_as_float(io.imread("test.png"))
h, w = pic.shape
b_coord, r_coord = align(pic, (0, 0))


b = pic[int(h*0.05):int(h//3-h*0.05), int(w*0.1):int(w-w*0.1)]
g = pic[int(h//3+h*0.05):int(h//3*2-h*0.05), int(w*0.1):int(w-w*0.1)]
r = pic[int(h//3*2+h*0.05):int(h//3*3-h*0.05), int(w*0.1):int(w-w*0.1)]

#io.imshow(dstack((r, g, b)))
b = roll(roll(b, b_coord[1], 0), b_coord[0], 1)
r = roll(roll(r, r_coord[1], 0), r_coord[0], 1)
io.imshow(dstack((r, g, b)))
# Out:
# --2025-03-19 23:31:48--  https://stepik.org/media/attachments/lesson/58182/08.png
# Resolving stepik.org (stepik.org)... 178.248.239.111
# Connecting to stepik.org (stepik.org)|178.248.239.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 307694 (300K) [image/png]
# Saving to: ‘test.png’
#
# test.png            100%[===================>] 300.48K   607KB/s    in 0.5s
#
# 2025-03-19 23:31:49 (607 KB/s) - ‘test.png’ saved [307694/307694]
# <ipython-input-142-19176ff9bd52>:74: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(dstack((r, g, b)))

# %% [markdown]
# *Примечание*: в задании рекомендуется обрезать 5% рамки, это не очень хороший совет. Лучше взять побольше: около 10%
